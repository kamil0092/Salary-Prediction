# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  33 non-null     float64
#  1   Salary           33 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 660.0 bytes

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        33.000000      33.000000
# mean          5.921212   82760.303030
# std           3.342413   34014.620992
# min           1.100000   37731.000000
# 25%           3.200000   56957.000000
# 50%           5.100000   67938.000000
# 75%           8.700000  109431.000000
# max          13.000000  156000.000000

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.983642
# Salary                  0.983642  1.000000

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
x = df.drop('Salary', axis=1)
y = df['Salary']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y,train_size=0.8, test_size=0.2, random_state=1234567)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

predictions = model.predict(x_test)
r2_score = r2_score(y_test, predictions)
print(f"r2 Sccore is : {r2_score:.4f}")
# Out:
# r2 Sccore is : 0.9481

# %%
# save the model to the file
import pickle

with open('salary_model.pkl', 'wb') as f1:
    pickle.dump(model, f1)

# %%
import pickle

with open('salary_model.pkl', "rb") as f1:
    res = pickle.load(f1)
    # print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 5
#       3 with open('salary_model.pkl', "rb") as f1:
#       4     res = pickle.load(f1)
# ----> 5     print(res[0])
#
# TypeError: 'LinearRegression' object is not subscriptable
